# %% [markdown]
# 5.3 Summary Table of Regression Results
# Summarize and output the coefficients, standard errors, and significance stars of the three models

# %%
# Generate academic standard table
results_table = summary_col(
    [m1, m2, m3], 
    stars=True, 
    float_format='%0.3f',
    model_names=['Model 1\n(Demo)', 'Model 2\n(+SES)', 'Model 3\n(+Full)'],
    info_dict={
        'N': lambda x: "{0:d}".format(int(x.nobs)),
        'R2': lambda x: "{:.3f}".format(x.rsquared),
        'Adj. R2': lambda x: "{:.3f}".format(x.rsquared_adj)
    },
    regressor_order=['Intercept', 'age', 'ln_income', 'education', 'social_class', 'health'] # Optional: specify display order
)

print(results_table)
